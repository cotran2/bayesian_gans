# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
generated = np.load('generated_sample.npy')
random = np.load('random_sample.npy')

# %%
generated.shape
# Out:
# (1, 10000, 2)

# %%
generated = generated[0,:,:]
random = random[0,:,:]

# %%
plt.hexbin(generated[:,0], generated[:,1], cmap='rainbow')
plt.gca().set_aspect('equal', adjustable='box')
plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.show()

# %%
plt.hexbin(random[:,0], random[:,1], cmap='rainbow')
plt.gca().set_aspect('equal', adjustable='box')
plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.show()

# %%
y_train = np.load('y_train.npy')

# %%
len(np.unique(y_train[0]))
# Out:
# 1068

# %%
y_train.shape
# Out:
# (10, 10000, 2)

# %%
y = np.unique(y_train[0],axis=0)
plt.hexbin(y[:,0], y[:,1], cmap='rainbow')
plt.gca().set_aspect('equal', adjustable='box')
plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.show()

# %%
len(y)
# Out:
# 534
