# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
generated = np.load('generated_sample_1.npy')
random = np.load('random_sample_1.npy')

# %%
generated
# Out:
# array([[ 0.24511431,  0.8629396 ],
#        [-0.4181642 ,  0.8909184 ],
#        [-0.39827538,  0.89082766],
#        ...,
#        [-0.5052955 ,  0.89270806],
#        [ 0.6942452 ,  0.8329937 ],
#        [ 0.23859565,  0.8627875 ]], dtype=float32)

# %%
generated = generated[0,:,:]
random = random[0,:,:]

# %%
plt.hexbin(generated[:,0], generated[:,1], cmap='rainbow')
plt.gca().set_aspect('equal', adjustable='box')
plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.show()

# %%
plt.hexbin(random[:,0], random[:,1], cmap='rainbow')
plt.gca().set_aspect('equal', adjustable='box')
plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.show()

# %%
y_train = np.load('y_train_1.npy')

# %%
len(np.unique(y_train[0]))
# Out:
# 2000

# %%
y_train[0]
# Out:
# array([[[-1.0937368 ],
#         [ 0.73620003]],
#
#        [[-1.09263   ],
#         [ 0.99615896]],
#
#        [[-1.0923798 ],
#         [ 0.5204752 ]],
#
#        ...,
#
#        [[ 2.1887958 ],
#         [ 1.0615911 ]],
#
#        [[ 2.4823282 ],
#         [ 0.62116545]],
#
#        [[ 2.6199548 ],
#         [ 0.712471  ]]], dtype=float32)

# %%
y = np.unique(y_train[0],axis=0)
plt.hexbin(y[:,0], y[:,1], cmap='rainbow')
plt.gca().set_aspect('equal', adjustable='box')
plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.show()

# %%
len(y)
# Out:
# 534
